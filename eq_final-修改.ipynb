# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
eq20_years = pd.read_csv('1999-2019.csv')
eq1_year = pd.read_csv('earthquake.csv')
eq_sichuan = pd.read_csv('sichuan.csv')

# %%
eq20_years.sample(5)
# Out:
#                             time  latitude  longitude  depth  mag magType  \
# 74054   2013-11-28T01:19:09.120Z   39.5265    73.6275  42.74  4.6      mb
# 130308  2000-05-24T16:44:48.130Z  -36.3180  -100.3810  10.00  4.5      mb
# 68053   2017-09-08T13:43:55.020Z   15.2494   -94.5913  35.03  4.5      mb
# 68166   2017-09-03T03:21:42.570Z   11.9775   -87.9271   8.23  5.0     mww
# 97082   2012-09-03T16:36:43.250Z    2.4360   -95.4050  10.00  4.7      mb
#
#           nst    gap   dmin   rms  ...                   updated  \
# 74054     NaN   59.0  1.870  0.85  ...  2014-02-12T01:08:35.000Z
# 130308    NaN    NaN    NaN  1.25  ...  2014-11-07T01:10:11.504Z
# 68053     NaN  150.0  1.550  1.40  ...  2017-12-07T20:00:22.040Z
# 68166     NaN  145.0  1.115  1.05  ...  2017-12-07T20:00:05.040Z
# 97082   163.0   79.9    NaN  0.76  ...  2014-11-07T01:48:46.493Z
#
#                                            place        type horizontalError  \
# 74054           39km SE of Sary-Tash, Kyrgyzstan  earthquake             NaN
# 130308                southeast of Easter Island  earthquake             NaN
# 68053   109km S of San Francisco del Mar, Mexico  earthquake             6.7
# 68166              99km SW of Corinto, Nicaragua  earthquake             6.4
# 97082          Galapagos Islands, Ecuador region  earthquake             NaN
#
#        depthError  magError  magNst    status  locationSource magSource
# 74054         6.9     0.081     NaN  reviewed              us        us
# 130308        NaN       NaN     2.0  reviewed              us        us
# 68053         8.9     0.089    37.0  reviewed              us        us
# 68166         4.3     0.066    22.0  reviewed              us        us
# 97082         NaN       NaN   127.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
eq20_years.iloc[6666]
# Out:
# time                  2010-05-10T00:25:29.740Z
# latitude                                -2.881
# longitude                              101.101
# depth                                     56.7
# mag                                        4.6
# magType                                     mb
# nst                                         25
# gap                                      180.7
# dmin                                       NaN
# rms                                       0.85
# net                                         us
# id                                  usp000hcjh
# updated               2014-11-07T01:41:28.481Z
# place              southern Sumatra, Indonesia
# type                                earthquake
# horizontalError                            NaN
# depthError                                   8
# magError                                   NaN
# magNst                                       3
# status                                reviewed
# locationSource                              us
# magSource                                   us
# Name: 6666, dtype: object

# %% [markdown]
# ### 1. 数据清洗
# - 选取出需要的字段
# - 数据类型转换

# %%
eq20_years.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
cols = ['time', 'latitude', 'longitude', 'depth', 'mag', 
        'magType', 'id', 'place', 'type', 'status']
eq20_years = eq20_years[cols]
eq1_year = eq1_year[cols]
eq_sichuan = eq_sichuan[cols]

# %%
eq20_years['time'] = pd.to_datetime(eq20_years['time'])
eq1_year['time'] = pd.to_datetime(eq1_year['time'])
eq_sichuan['time'] = pd.to_datetime(eq_sichuan['time'])

# %% [markdown]
# ### 2. 问题
# - 最近地震越来越频繁了吗？还是报道的比较多而已？
# - 引发地震的因素有哪些？
# - 全世界地震频发的地区有哪些？
# - 有哪些引发全世界舆情关注的大地震？
# - 为什么四川省及其周围好像从2008年开始就地震频发？

# %% [markdown]
# #### 2.1 最近地震越来越频繁了吗？还是报道的比较多而已？

# %%
eq20_years.sample(5)
# Out:
#                                    time  latitude  longitude   depth  mag  \
# 63743  2018-04-23 15:48:52.860000+00:00   36.0172     0.0472    8.04  4.7
# 49562  2016-10-15 02:44:48.820000+00:00  -24.1129   -66.8771  193.41  4.5
# 120256 2011-11-09 05:24:38.080000+00:00   36.2810   140.8810   37.10  4.8
# 106011 2004-07-10 04:14:19.530000+00:00  -36.8450    78.3570   10.00  4.8
# 98247  2012-06-30 00:46:49.010000+00:00   43.4420    84.8960   10.00  4.5
#
#        magType          id                                             place  \
# 63743       mb  us1000dqq7                   10km NNW of Mostaganem, Algeria
# 49562       mb  us20007eaa  57km WNW of San Antonio de los Cobres, Argentina
# 120256      mb  usp000jam3              near the east coast of Honshu, Japan
# 106011      mb  usp000czw2                                  Mid-Indian Ridge
# 98247       mb  usp000jnda                          northern Xinjiang, China
#
#               type    status
# 63743   earthquake  reviewed
# 49562   earthquake  reviewed
# 120256  earthquake  reviewed
# 106011  earthquake  reviewed
# 98247   earthquake  reviewed

# %%
eq20_years.index = eq20_years['time']
eq20_years['year'] = eq20_years['time'].dt.year

# %%
eq20_years['time'].describe()
# Out:
# <ipython-input-10-111cfbeddf4e>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   eq20_years['time'].describe()
# count                               134063
# unique                              134062
# top       2001-12-28 21:14:01.950000+00:00
# freq                                     2
# first     1999-06-25 00:13:36.590000+00:00
# last      2019-06-24 13:55:59.891000+00:00
# Name: time, dtype: object

# %%
# 选取2000年1月1日到2019年6月24日的数据
eq20_years = eq20_years[eq20_years['time'] > pd.to_datetime('2000-01-01 00:00:00', utc=True)]

# %%
eq20_years['mag'].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
eq_by_years = eq20_years['id'].groupby(eq20_years['year']).count()

# %%
eq_by_years[:-1].mean()
# Out:
# 6764.105263157895

# %%
from pyecharts import Bar


bar = Bar("近20年全球4.5级以上地震发生次数", "时间: 2000年1月1日-2019年6月24日", width=700)
bar.add("", list(eq_by_years.index), list(eq_by_years.values),
        is_stack=True,  bar_category_gap='40%', label_text_size=18,
       legend_text_size=18,xaxis_label_textsize=16,yaxis_label_textsize=18,
       mark_line_raw = [{'yAxis':6764}])

bar
# Out:
# ERROR:lml.utils:failed to import pyecharts_snapshot
# Traceback (most recent call last):
#   File "C:\Users\Administrator\anaconda3\lib\site-packages\lml\utils.py", line 43, in do_import
#     plugin_module = __import__(plugin_module_name)
# ModuleNotFoundError: No module named 'pyecharts_snapshot'
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="7edd396521584f21a6e4e3699d50eeab" style="width:700px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_7edd396521584f21a6e4e3699d50eeab = echarts.init(document.getElementById('7edd396521584f21a6e4e3699d50eeab'), 'light', {renderer: 'canvas'});
#
# var option_7edd396521584f21a6e4e3699d50eeab = {
#     "title": [
#         {
#             "text": "\u8fd120\u5e74\u5168\u74034.5\u7ea7\u4ee5\u4e0a\u5730\u9707\u53d1\u751f\u6b21\u6570",
#             "subtext": "\u65f6\u95f4: 2000\u5e741\u67081\u65e5-2019\u5e746\u670824\u65e5",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3271207,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 5009.0,
#                 4680.0,
#                 4962.0,
#                 5140.0,
#                 6183.0,
#                 7881.0,
#                 7078.0,
#                 7274.0,
#                 6309.0,
#                 6055.0,
#                 7211.0,
#                 9578.0,
#                 7165.0,
#                 7201.0,
#                 8313.0,
#                 7139.0,
#                 7426.0,
#                 6362.0,
#                 7552.0,
#                 3347.0
#             ],
#             "stack": "stack_3271207",
#             "barCategoryGap": "40%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 18
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "yAxis": 6764
#                     }
#                 ]
#             },
#             "seriesId": 3271207
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16
#                 }
#             },
#             "data": [
#                 2000,
#                 2001,
#                 2002,
#                 2003,
#                 2004,
#                 2005,
#                 2006,
#                 2007,
#                 2008,
#                 2009,
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2014,
#                 2015,
#                 2016,
#                 2017,
#                 2018,
#                 2019
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_7edd396521584f21a6e4e3699d50eeab.setOption(option_7edd396521584f21a6e4e3699d50eeab);
#
#     });
# </script>

# %%
6764-6309
# Out:
# 455

# %%
eq_by_years_7 = eq20_years[eq20_years['mag']>7].groupby('year')['id'].count()

# %%
eq_by_years_7[:-1].mean()
# Out:
# 12.789473684210526

# %%
from pyecharts import Bar


bar = Bar("近20年全球7级以上地震发生次数", "时间: 2000年1月1日-2019年6月24日", width=700)
bar.add("", list(eq_by_years_7.index), list(eq_by_years_7.values),
        is_stack=True,  bar_category_gap='40%', label_text_size=18,
       legend_text_size=18,xaxis_label_textsize=16,yaxis_label_textsize=18,
       mark_line_raw = [{'yAxis':12.8}])

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="88e013c8c8b7470a99eff41adfd6c79b" style="width:700px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_88e013c8c8b7470a99eff41adfd6c79b = echarts.init(document.getElementById('88e013c8c8b7470a99eff41adfd6c79b'), 'light', {renderer: 'canvas'});
#
# var option_88e013c8c8b7470a99eff41adfd6c79b = {
#     "title": [
#         {
#             "text": "\u8fd120\u5e74\u5168\u74037\u7ea7\u4ee5\u4e0a\u5730\u9707\u53d1\u751f\u6b21\u6570",
#             "subtext": "\u65f6\u95f4: 2000\u5e741\u67081\u65e5-2019\u5e746\u670824\u65e5",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7098146,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 11.0,
#                 13.0,
#                 13.0,
#                 12.0,
#                 13.0,
#                 10.0,
#                 9.0,
#                 17.0,
#                 9.0,
#                 15.0,
#                 17.0,
#                 15.0,
#                 15.0,
#                 15.0,
#                 11.0,
#                 14.0,
#                 13.0,
#                 6.0,
#                 15.0,
#                 6.0
#             ],
#             "stack": "stack_7098146",
#             "barCategoryGap": "40%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 18
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "yAxis": 12.8
#                     }
#                 ]
#             },
#             "seriesId": 7098146
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16
#                 }
#             },
#             "data": [
#                 2000,
#                 2001,
#                 2002,
#                 2003,
#                 2004,
#                 2005,
#                 2006,
#                 2007,
#                 2008,
#                 2009,
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2014,
#                 2015,
#                 2016,
#                 2017,
#                 2018,
#                 2019
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_88e013c8c8b7470a99eff41adfd6c79b.setOption(option_88e013c8c8b7470a99eff41adfd6c79b);
#
#     });
# </script>

# %%
eq_by_month = eq20_years['id'].resample('M').count().reset_index()

# %%
eq_by_month['year'] = eq_by_month['time'].dt.year

# %%
eq_by_month.tail(6)
# Out:
#                          time   id  year
# 228 2019-01-31 00:00:00+00:00  654  2019
# 229 2019-02-28 00:00:00+00:00  560  2019
# 230 2019-03-31 00:00:00+00:00  617  2019
# 231 2019-04-30 00:00:00+00:00  636  2019
# 232 2019-05-31 00:00:00+00:00  521  2019
# 233 2019-06-30 00:00:00+00:00  359  2019

# %%
from pyecharts import Line


month_name = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']
line = Line("近5年全球每月4.5级以上地震次数", width=800, height=400)
for y in range(2015, 2019):
    sub_data = eq_by_month[eq_by_month['year'] == y]
    line.add(str(y), month_name, list(sub_data['id']), is_smooth=True,
             legend_text_size=15,xaxis_label_textsize=16, yaxis_label_textsize=18,legend_top=30)

line.add('2019', month_name, [654, 560, 617, 636, 521, 359, None, None, None, None, None, None], is_smooth=True,
             legend_text_size=15,xaxis_label_textsize=16,
             yaxis_label_textsize=18,legend_top=30)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="727f1e25bc3b4bceb4bec419c07f91a5" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_727f1e25bc3b4bceb4bec419c07f91a5 = echarts.init(document.getElementById('727f1e25bc3b4bceb4bec419c07f91a5'), 'light', {renderer: 'canvas'});
#
# var option_727f1e25bc3b4bceb4bec419c07f91a5 = {
#     "title": [
#         {
#             "text": "\u8fd15\u5e74\u5168\u7403\u6bcf\u67084.5\u7ea7\u4ee5\u4e0a\u5730\u9707\u6b21\u6570",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 586562,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "2015",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1\u6708",
#                     556
#                 ],
#                 [
#                     "2\u6708",
#                     519
#                 ],
#                 [
#                     "3\u6708",
#                     520
#                 ],
#                 [
#                     "4\u6708",
#                     524
#                 ],
#                 [
#                     "5\u6708",
#                     711
#                 ],
#                 [
#                     "6\u6708",
#                     515
#                 ],
#                 [
#                     "7\u6708",
#                     601
#                 ],
#                 [
#                     "8\u6708",
#                     542
#                 ],
#                 [
#                     "9\u6708",
#                     886
#                 ],
#                 [
#                     "10\u6708",
#                     521
#                 ],
#                 [
#                     "11\u6708",
#                     635
#                 ],
#                 [
#                     "12\u6708",
#                     609
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 586562
#         },
#         {
#             "type": "line",
#             "name": "2016",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1\u6708",
#                     536
#                 ],
#                 [
#                     "2\u6708",
#                     498
#                 ],
#                 [
#                     "3\u6708",
#                     465
#                 ],
#                 [
#                     "4\u6708",
#                     692
#                 ],
#                 [
#                     "5\u6708",
#                     530
#                 ],
#                 [
#                     "6\u6708",
#                     574
#                 ],
#                 [
#                     "7\u6708",
#                     577
#                 ],
#                 [
#                     "8\u6708",
#                     727
#                 ],
#                 [
#                     "9\u6708",
#                     753
#                 ],
#                 [
#                     "10\u6708",
#                     480
#                 ],
#                 [
#                     "11\u6708",
#                     716
#                 ],
#                 [
#                     "12\u6708",
#                     878
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 586562
#         },
#         {
#             "type": "line",
#             "name": "2017",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1\u6708",
#                     613
#                 ],
#                 [
#                     "2\u6708",
#                     465
#                 ],
#                 [
#                     "3\u6708",
#                     484
#                 ],
#                 [
#                     "4\u6708",
#                     517
#                 ],
#                 [
#                     "5\u6708",
#                     538
#                 ],
#                 [
#                     "6\u6708",
#                     393
#                 ],
#                 [
#                     "7\u6708",
#                     488
#                 ],
#                 [
#                     "8\u6708",
#                     461
#                 ],
#                 [
#                     "9\u6708",
#                     624
#                 ],
#                 [
#                     "10\u6708",
#                     520
#                 ],
#                 [
#                     "11\u6708",
#                     733
#                 ],
#                 [
#                     "12\u6708",
#                     526
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }

# %% [markdown]
# #### 2.2 引发地震的因素有哪些？

# %%
eq1_year.sample(5)
# Out:
#                                    time   latitude   longitude  depth   mag  \
# 45240  2018-07-18 00:35:24.250000+00:00  38.836667 -122.823500   1.32  1.81
# 9818   2018-10-31 06:48:21.420000+00:00  33.676833 -117.360167   9.01  0.78
# 95255  2019-04-22 14:59:08.960000+00:00  33.315833 -116.287833   9.92  1.26
# 108699 2018-12-27 21:08:37.176000+00:00  61.447200 -149.950700  31.00  2.10
# 18805  2018-12-06 08:05:23.963000+00:00  64.878600 -149.020300  14.10  0.40
#
#        magType          id                           place        type  \
# 45240       md  nc73048531       9km NW of The Geysers, CA  earthquake
# 9818        ml  ci37409274    3km WNW of Lake Elsinore, CA  earthquake
# 95255       ml  ci38556024  10km NE of Borrego Springs, CA  earthquake
# 108699      ml  ak20560208       8km S of Big Lake, Alaska  earthquake
# 18805       ml  ak20449351  33km N of North Nenana, Alaska  earthquake
#
#            status
# 45240    reviewed
# 9818     reviewed
# 95255    reviewed
# 108699  automatic
# 18805    reviewed

# %%
eq_type = eq1_year['type'].value_counts()
eq_type
# Out:
# earthquake            158194
# quarry blast            1173
# explosion               1023
# ice quake                776
# mining explosion         214
# other event              136
# volcanic eruption         28
# chemical explosion        15
# mine collapse              2
# sonic boom                 2
# rock burst                 2
# Name: type, dtype: int64

# %%
np.round(eq_type/eq_type.sum()*100, 2)
# Out:
# earthquake            97.91
# quarry blast           0.73
# explosion              0.63
# ice quake              0.48
# mining explosion       0.13
# other event            0.08
# volcanic eruption      0.02
# chemical explosion     0.01
# mine collapse          0.00
# sonic boom             0.00
# rock burst             0.00
# Name: type, dtype: float64

# %%
eq1_year['time'].describe()
# Out:
# <ipython-input-27-32d015f2f9bb>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   eq1_year['time'].describe()
# count                               161565
# unique                              161552
# top       2018-08-03 21:16:00.990000+00:00
# freq                                     2
# first     2018-06-25 00:01:27.580000+00:00
# last      2019-06-24 06:52:27.530000+00:00
# Name: time, dtype: object

# %%
eq_type
# Out:
# earthquake            158194
# quarry blast            1173
# explosion               1023
# ice quake                776
# mining explosion         214
# other event              136
# volcanic eruption         28
# chemical explosion        15
# mine collapse              2
# sonic boom                 2
# rock burst                 2
# Name: type, dtype: int64

# %%
from pyecharts import Sankey

nodes = [
    {'name': '构造地震'}, {'name': '天然地震'}, {'name': '火山喷发'},
    {'name': '火山地震'}, {'name': '冰震'}, {'name': '塌陷地震'},
    {'name': '矿井塌陷'}, {'name': '岩爆'}, {'name': '采石场爆破'},
    {'name': '爆炸'}, {'name': '煤矿爆炸'}, {'name': '化学爆炸'},
    {'name': '人工地震'}, {'name': '水库地震'}, {'name': '油田注水'},
    {'name': '诱发地震'}
]

links = [
    {'source': '构造地震', 'target': '天然地震', 'value': 5000},  #为了图形显示，这里重置了构造地震真实值
    {'source': '火山喷发', 'target': '火山地震', 'value': 28},
    {'source': '火山地震', 'target': '天然地震', 'value': 28},
    {'source': '冰震', 'target': '塌陷地震', 'value': 776},
    {'source': '矿井塌陷', 'target': '塌陷地震', 'value': 2},
    {'source': '岩爆', 'target': '塌陷地震', 'value': 2},
    {'source': '塌陷地震', 'target': '天然地震', 'value': 780},
    {'source': '采石场爆破', 'target': '人工地震', 'value': 1173},
    {'source': '爆炸', 'target': '人工地震', 'value': 1023},
    {'source': '煤矿爆炸', 'target': '人工地震', 'value': 214},
    {'source': '化学爆炸', 'target': '人工地震', 'value': 15},
    {'source': '水库地震', 'target': '诱发地震', 'value': 50},
    {'source': '油田注水', 'target': '诱发地震', 'value': 50},
]
sankey = Sankey("近一年全球所有地震的地震类型", "时间: 2018年6月25日至2019年6月24日", width=800, height=900)
sankey.add(
    "",
    nodes,
    links,
    line_opacity=0.2,
    line_curve=0.5,
    line_color="source",
    is_label_show=True,
    label_pos="right",
)
sankey
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="02de041acecb494098915b15c90d26d6" style="width:800px;height:900px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_02de041acecb494098915b15c90d26d6 = echarts.init(document.getElementById('02de041acecb494098915b15c90d26d6'), 'light', {renderer: 'canvas'});
#
# var option_02de041acecb494098915b15c90d26d6 = {
#     "title": [
#         {
#             "text": "\u8fd1\u4e00\u5e74\u5168\u7403\u6240\u6709\u5730\u9707\u7684\u5730\u9707\u7c7b\u578b",
#             "subtext": "\u65f6\u95f4: 2018\u5e746\u670825\u65e5\u81f32019\u5e746\u670824\u65e5",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2856434,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "sankey",
#             "data": [
#                 {
#                     "name": "\u6784\u9020\u5730\u9707"
#                 },
#                 {
#                     "name": "\u5929\u7136\u5730\u9707"
#                 },
#                 {
#                     "name": "\u706b\u5c71\u55b7\u53d1"
#                 },
#                 {
#                     "name": "\u706b\u5c71\u5730\u9707"
#                 },
#                 {
#                     "name": "\u51b0\u9707"
#                 },
#                 {
#                     "name": "\u584c\u9677\u5730\u9707"
#                 },
#                 {
#                     "name": "\u77ff\u4e95\u584c\u9677"
#                 },
#                 {
#                     "name": "\u5ca9\u7206"
#                 },
#                 {
#                     "name": "\u91c7\u77f3\u573a\u7206\u7834"
#                 },
#                 {
#                     "name": "\u7206\u70b8"
#                 },
#                 {
#                     "name": "\u7164\u77ff\u7206\u70b8"
#                 },
#                 {
#                     "name": "\u5316\u5b66\u7206\u70b8"
#                 },
#                 {
#                     "name": "\u4eba\u5de5\u5730\u9707"
#                 },
#                 {
#                     "name": "\u6c34\u5e93\u5730\u9707"
#                 },
#                 {
#                     "name": "\u6cb9\u7530\u6ce8\u6c34"
#                 },
#                 {
#                     "name": "\u8bf1\u53d1\u5730\u9707"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "\u6784\u9020\u5730\u9707",
#                     "target": "\u5929\u7136\u5730\u9707",
#                     "value": 5000
#                 },
#                 {
#                     "source": "\u706b\u5c71\u55b7\u53d1",
#                     "target": "\u706b\u5c71\u5730\u9707",
#                     "value": 28
#                 },
#                 {
#                     "source": "\u706b\u5c71\u5730\u9707",
#                     "target": "\u5929\u7136\u5730\u9707",
#                     "value": 28
#                 },
#                 {
#                     "source": "\u51b0\u9707",
#                     "target": "\u584c\u9677\u5730\u9707",
#                     "value": 776
#                 },
#                 {
#                     "source": "\u77ff\u4e95\u584c\u9677",
#                     "target": "\u584c\u9677\u5730\u9707",
#                     "value": 2
#                 },
#                 {
#                     "source": "\u5ca9\u7206",
#                     "target": "\u584c\u9677\u5730\u9707",
#                     "value": 2
#                 },
#                 {
#                     "source": "\u584c\u9677\u5730\u9707",
#                     "target": "\u5929\u7136\u5730\u9707",
#                     "value": 780
#                 },
#                 {
#                     "source": "\u91c7\u77f3\u573a\u7206\u7834",
#                     "target": "\u4eba\u5de5\u5730\u9707",
#                     "value": 1173
#                 },
#                 {
#                     "source": "\u7206\u70b8",
#                     "target": "\u4eba\u5de5\u5730\u9707",
#                     "value": 1023
#                 },
#                 {
#                     "source": "\u7164\u77ff\u7206\u70b8",
#                     "target": "\u4eba\u5de5\u5730\u9707",
#                     "value": 214
#                 },
#                 {
#                     "source": "\u5316\u5b66\u7206\u70b8",
#                     "target": "\u4eba\u5de5\u5730\u9707",
#                     "value": 15
#                 },
#                 {
#                     "source": "\u6c34\u5e93\u5730\u9707",
#                     "target": "\u8bf1\u53d1\u5730\u9707",
#                     "value": 50
#                 },
#                 {
#                     "source": "\u6cb9\u7530\u6ce8\u6c34",
#                     "target": "\u8bf1\u53d1\u5730\u9707",
#                     "value": 50
#                 }
#             ],
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "right",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 0.2,
#                     "curveness": 0.5,
#                     "type": "solid",
#                     "color": "source"
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_02de041acecb494098915b15c90d26d6.setOption(option_02de041acecb494098915b15c90d26d6);
#
#     });
# </script>

# %%
eq1_year.shape
# Out:
# (161565, 10)

# %% [markdown]
# #### 2.3 全世界地震频发的地区有哪些？

# %%
eq20_years.shape
# Out:
# (131865, 11)

# %%
eq20_years.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'id',
#        'place', 'type', 'status', 'year'],
#       dtype='object')

# %%
eq_place = eq20_years.sample(30000)[['latitude', 'longitude', 'mag']]
eq_place['latitude'] = eq_place['latitude'].astype(str)
eq_place['longitude'] = eq_place['longitude'].astype(str)
eq_place['latlon'] = eq_place['longitude'].str.cat(eq_place['latitude'], sep=',')

# %%
eq_place.to_csv('eq_place.csv', index=False)

# %%
eq20_years[eq20_years['mag'] > 6].shape
# Out:
# (2343, 11)

# %%
eq_place_6 = eq20_years[eq20_years['mag'] > 6]
eq_place_6['latitude'] = eq_place_6['latitude'].astype(str)
eq_place_6['longitude'] = eq_place_6['longitude'].astype(str)
eq_place_6['latlon'] = eq_place_6['longitude'].str.cat(eq_place_6['latitude'], sep=',')

eq_place_6.to_csv('eq_place_6.csv', index=False)
# Out:
# <ipython-input-36-da624fa49e4f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eq_place_6['latitude'] = eq_place_6['latitude'].astype(str)
# <ipython-input-36-da624fa49e4f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eq_place_6['longitude'] = eq_place_6['longitude'].astype(str)
# <ipython-input-36-da624fa49e4f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eq_place_6['latlon'] = eq_place_6['longitude'].str.cat(eq_place_6['latitude'], sep=',')

# %%
region = []
for l in eq20_years['place'].str.split(',').tolist():
    try:
        region.append(l[-1].strip())
    except TypeError:
        region.append(np.nan)

# %%
eq20_years['region'] = region

# %%
region_top10 = eq20_years['region'].value_counts().nlargest(11)
region_top10
# Out:
# Indonesia           15661
# Japan                9646
# Papua New Guinea     7827
# Chile                5249
# Philippines          4379
# Tonga                4167
# Vanuatu              3489
# New Zealand          2982
# Solomon Islands      2958
# Alaska               2700
# Japan region         2522
# Name: region, dtype: int64

# %%
from pyecharts import Bar


r = ['印尼', '日本', '新几内亚', '智利', '菲律宾', '汤加', '瓦努阿图', '新西兰', '所罗门群岛', '阿拉斯加州']
num = [15661, 9646+2522, 7827, 5249, 4379, 4167, 3489, 2982, 2958, 2700]
bar = Bar("近20年全球4.5级以上地震次数最多的国家/地区", "时间: 2000年1月1日-2019年6月24日, 单位:次", width=900)
bar.add("", r, num, 
        is_stack=True,  bar_category_gap='40%', label_text_size=18, 
        xaxis_label_textsize=11,yaxis_label_textsize=20, xaxis_rotate=0)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4ace1141b44643a798e67a616c7d746c" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4ace1141b44643a798e67a616c7d746c = echarts.init(document.getElementById('4ace1141b44643a798e67a616c7d746c'), 'light', {renderer: 'canvas'});
#
# var option_4ace1141b44643a798e67a616c7d746c = {
#     "title": [
#         {
#             "text": "\u8fd120\u5e74\u5168\u74034.5\u7ea7\u4ee5\u4e0a\u5730\u9707\u6b21\u6570\u6700\u591a\u7684\u56fd\u5bb6/\u5730\u533a",
#             "subtext": "\u65f6\u95f4: 2000\u5e741\u67081\u65e5-2019\u5e746\u670824\u65e5, \u5355\u4f4d:\u6b21",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2957932,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 15661,
#                 12168,
#                 7827,
#                 5249,
#                 4379,
#                 4167,
#                 3489,
#                 2982,
#                 2958,
#                 2700
#             ],
#             "stack": "stack_2957932",
#             "barCategoryGap": "40%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 18
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2957932
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 11
#                 }
#             },
#             "data": [
#                 "\u5370\u5c3c",
#                 "\u65e5\u672c",
#                 "\u65b0\u51e0\u5185\u4e9a",
#                 "\u667a\u5229",
#                 "\u83f2\u5f8b\u5bbe",
#                 "\u6c64\u52a0",
#                 "\u74e6\u52aa\u963f\u56fe",
#                 "\u65b0\u897f\u5170",
#                 "\u6240\u7f57\u95e8\u7fa4\u5c9b",
#                 "\u963f\u62c9\u65af\u52a0\u5dde"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 20
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_4ace1141b44643a798e67a616c7d746c.setOption(option_4ace1141b44643a798e67a616c7d746c);
#
#     });
# </script>

# %% [markdown]
# #### 2.4 近20年有哪些引发全世界舆情关注的大地震？

# %%
eq_gt_6 = eq20_years[eq20_years['mag'] > 6]

# %%
eq_gt_6[eq_gt_6['mag']<7].shape[0]
# Out:
# 2041

# %%
eq_gt_6[(eq_gt_6['mag']>=7)&(eq_gt_6['mag']<8)].shape[0]
# Out:
# 278

# %%
eq_gt_6[(eq_gt_6['mag']>=8)&(eq_gt_6['mag']<9)].shape[0]
# Out:
# 22

# %%
eq_gt_6[eq_gt_6['mag']>=9].shape[0]
# Out:
# 2

# %%
eq_gt_7 = eq20_years[eq20_years['mag'] > 7]

# %%
eq_gt_7['influence'] = eq_gt_7['mag'] + np.round(10/(eq_gt_7['depth']+5))
# Out:
# <ipython-input-47-b6237f41f3df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eq_gt_7['influence'] = eq_gt_7['mag'] + np.round(10/(eq_gt_7['depth']+5))

# %%
eq_gt_7.loc[eq_gt_7.sort_values(by=['mag', 'depth'], ascending=[False, True]).index].head(30)
# Out:
#                                                              time  latitude  \
# time
# 2011-03-11 05:46:24.120000+00:00 2011-03-11 05:46:24.120000+00:00   38.2970
# 2004-12-26 00:58:53.450000+00:00 2004-12-26 00:58:53.450000+00:00    3.2950
# 19   2019-01-07 17:15:44.420000+00:00   26.7955    99.4683   10.0  4.5
#
#      magType          id                     place        type    status
# 733       mb  usp000bmap            eastern Xizang  earthquake  reviewed
# 256       mb  usp000ja74              Gansu, China  earthquake  reviewed
# 1012      mb  usp0002qrg            eastern Xizang  earthquake  reviewed
# 1034      mb  usp0001z2s    western Sichuan, China  earthquake  reviewed
# 19        mb  us2000j159  39km N of Jinding, China  earthquake  reviewed

# %%
eq_sichuan[['latitude', 'longitude', 'mag']].describe()
# Out:
#           latitude    longitude          mag
# count  1073.000000  1073.000000  1073.000000
# mean     30.260878   102.387508     4.803914
# std       2.324542     2.668046     0.352342
# min      25.820000    96.504000     4.500000
# 25%      28.264900   100.099000     4.600000
# 50%      30.883000   103.473700     4.700000
# 75%      31.829000   104.315000     4.900000
# max      35.624000   108.807600     7.900000

# %%
eq_sichuan['time'].describe()
# Out:
# <ipython-input-52-0da9da4915f0>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   eq_sichuan['time'].describe()
# count                                 1073
# unique                                1073
# top       2019-02-23 21:38:10.120000+00:00
# freq                                     1
# first     1979-08-05 05:18:22.500000+00:00
# last      2019-06-24 01:23:16.859000+00:00
# Name: time, dtype: object

# %%
eq_sichuan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1073 entries, 0 to 1072
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   time       1073 non-null   datetime64[ns, UTC]
#  1   latitude   1073 non-null   float64
#  2   longitude  1073 non-null   float64
#  3   depth      1073 non-null   float64
#  4   mag        1073 non-null   float64
#  5   magType    1073 non-null   object
#  6   id         1073 non-null   object
#  7   place      1073 non-null   object
#  8   type       1073 non-null   object
#  9   status     1073 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(4), object(5)
# memory usage: 84.0+ KB

# %%
eq_sichuan['year'] = eq_sichuan['time'].dt.year

# %%
eq_sichuan_years = eq_sichuan.groupby('year')['id'].count()

# %%
from pyecharts import Line


line = Line("近40年四川省及其周围4.5级以上地震次数", width=800, height=400)

line.add('', eq_sichuan_years.index, eq_sichuan_years.values, is_smooth=True,
             legend_text_size=15,xaxis_label_textsize=16,
             yaxis_label_textsize=18)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="324b0a11eb9c49388f461f127b879e59" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_324b0a11eb9c49388f461f127b879e59 = echarts.init(document.getElementById('324b0a11eb9c49388f461f127b879e59'), 'light', {renderer: 'canvas'});
#
# var option_324b0a11eb9c49388f461f127b879e59 = {
#     "title": [
#         {
#             "text": "\u8fd140\u5e74\u56db\u5ddd\u7701\u53ca\u5176\u5468\u56f44.5\u7ea7\u4ee5\u4e0a\u5730\u9707\u6b21\u6570",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7167963,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     1979,
#                     3.0
#                 ],
#                 [
#                     1980,
#                     7.0
#                 ],
#                 [
#                     1981,
#                     11.0
#                 ],
#                 [
#                     1982,
#                     9.0
#                 ],
#                 [
#                     1983,
#                     10.0
#                 ],
#                 [
#                     1984,
#                     8.0
#                 ],
#                 [
#                     1985,
#                     10.0
#                 ],
#                 [
#                     1986,
#                     16.0
#                 ],
#                 [
#                     1987,
#                     8.0
#                 ],
#                 [
#                     1988,
#                     17.0
#                 ],
#                 [
#                     1989,
#                     54.0
#                 ],
#                 [
#                     1990,
#                     15.0
#                 ],
#                 [
#                     1991,
#                     12.0
#                 ],
#                 [
#                     1992,
#                     11.0
#                 ],
#                 [
#                     1993,
#                     15.0
#                 ],
#                 [
#                     1994,
#                     7.0
#                 ],
#                 [
#                     1995,
#                     18.0
#                 ],
#                 [
#                     1996,
#                     26.0
#                 ],
#                 [
#                     1997,
#                     19.0
#                 ],
#                 [
#                     1998,
#                     10.0
#                 ],
#                 [
#                     1999,
#                     9.0
#                 ],
#                 [
#                     2000,
#                     18.0
#                 ],
#                 [
#                     2001,
#                     16.0
#                 ],
#                 [
#                     2002,
#                     11.0
#                 ],
#                 [
#                     2003,
#                     18.0
#                 ],
#                 [
#                     2004,
#                     16.0
#                 ],
#                 [
#                     2005,
#                     10.0
#                 ],
#                 [
#                     2006,
#                     13.0
#                 ],
#                 [
#                     2007,
#                     6.0
#                 ],
#                 [
#                     2008,
#                     340.0
#                 ],
#                 [
#                     2009,
#                     31.0
#                 ],
#                 [
#                     2010,
#                     27.0
#                 ],
#                 [
#                     2011,
#                     21.0
#                 ],
#                 [
#                     2012,
#                     17.0
#                 ],
#                 [
#                     2013,
#                     71.0
#                 ],
#                 [
#                     2014,
#                     43.0
#                 ],
#                 [
#                     2015,
#                     20.0
#                 ],
#                 [
#                     2016,
#                     24.0
#                 ],
#                 [
#                     2017,
#                     31.0
#                 ],
#                 [
#                     2018,
#                     24.0
#                 ],
#                 [
#                     2019,
#                     21.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7167963
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 15
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16
#                 }
#             },
#             "data": [
#                 1979.0,
#                 1980.0,
#                 1981.0,
#                 1982.0,
#                 1983.0,
#                 1984.0,
#                 1985.0,
#                 1986.0,
#                 1987.0,
#                 1988.0,
#                 1989.0,
#                 1990.0,
#                 1991.0,
#                 1992.0,
#                 1993.0,
#                 1994.0,

# %%
eq_sichuan_years.loc[2009:2018].mean()
# Out:
# 30.9

# %%
eq_sichuan_years.loc[1979:2007].mean()
# Out:
# 13.89655172413793

# %%
eq_sichuan_years.values
# Out:
# array([  3,   7,  11,   9,  10,   8,  10,  16,   8,  17,  54,  15,  12,
#         11,  15,   7,  18,  26,  19,  10,   9,  18,  16,  11,  18,  16,
#         10,  13,   6, 340,  31,  27,  21,  17,  71,  43,  20,  24,  31,
#         24,  21], dtype=int64)

# %%
eq_sichuan[eq_sichuan['mag']>6]
# Out:
#                                  time  latitude  longitude  depth  mag  \
# 58   2017-08-08 13:19:49.540000+00:00   33.1926   103.8552    9.0  6.5
# 146  2014-08-03 08:30:13.570000+00:00   27.1891   103.4086   12.0  6.2
# 223  2013-04-20 00:02:47.540000+00:00   30.3080   102.8880   14.0  6.6
# 291  2010-04-13 23:49:38.330000+00:00   33.1650    96.5480   17.0  6.9
# 445  2008-05-25 08:21:49.990000+00:00   32.5600   105.4230   18.0  6.1
# 592  2008-05-12 11:11:02.480000+00:00   31.2140   103.6180   10.0  6.1
# 663  2008-05-12 06:28:01.570000+00:00   31.0020   103.3220   19.0  7.9
# 771  2000-09-12 00:27:58.620000+00:00   35.3890    99.3430   10.0  6.1
# 774  2000-06-07 21:46:55.900000+00:00   26.8560    97.2380   33.0  6.3
# 841  1996-02-03 11:14:20.120000+00:00   27.2910   100.2760   11.1  6.6
# 852  1995-10-23 22:46:50.810000+00:00   26.0030   102.2270   10.0  6.2
# 924  1989-09-22 02:25:50.880000+00:00   31.5830   102.4330   14.6  6.1
# 952  1989-05-03 05:53:01.170000+00:00   30.0910    99.4750   14.0  6.2
# 962  1989-04-25 02:13:20.830000+00:00   30.0480    99.4190    7.7  6.1
# 968  1989-04-15 20:34:08.930000+00:00   29.9870    99.1950   13.3  6.4
# 1062 1981-01-23 21:13:51.700000+00:00   30.9270   101.0980   33.0  6.8
#
#      magType          id                                place        type  \
# 58       mww  us2000a5x1            36km WSW of Yongle, China  earthquake
# 146      mww  usb000rzmg             11km W of Wenping, China  earthquake
# 223      mww  usb000gcdd          56km WSW of Linqiong, China  earthquake
# 291      mwc  usp000hbbt              southern Qinghai, China  earthquake
# 445      mwc  usp000g7r4   Sichuan-Gansu border region, China  earthquake
# 592      mwc  usp000g68b               eastern Sichuan, China  earthquake
# 663      mwc  usp000g650               eastern Sichuan, China  earthquake
# 771      mwc  usp000a03h              southern Qinghai, China  earthquake
# 774      mwc  usp0009u6j                              Myanmar  earthquake
# 841       mw  usp0007c7g  Sichuan-Yunnan border region, China  earthquake
# 852       mw  usp00075n1  Sichuan-Yunnan border region, China  earthquake
# 924       mw  usp0003zvq               western Sichuan, China  earthquake
# 952       mw  usp0003uu0               western Sichuan, China  earthquake
# 962       mw  usp0003uc7               western Sichuan, China  earthquake
# 968       mw  usp0003u05               western Sichuan, China  earthquake
# 1062      ms  usp0001bve               western Sichuan, China  earthquake
#
#         status  year
# 58    reviewed  2017
# 146   reviewed  2014
# 223   reviewed  2013
# 291   reviewed  2010
# 445   reviewed  2008
# 592   reviewed  2008
# 663   reviewed  2008
# 771   reviewed  2000
# 774   reviewed  2000
# 841   reviewed  1996
# 852   reviewed  1995
# 924   reviewed  1989
# 952   reviewed  1989
# 962   reviewed  1989
# 968   reviewed  1989
# 1062  reviewed  1981

# %%
eq_sichuan['latitude'] = eq_sichuan['latitude'].astype(str)
eq_sichuan['longitude'] = eq_sichuan['longitude'].astype(str)
eq_sichuan['latlon'] = eq_sichuan['longitude'].str.cat(eq_sichuan['latitude'], sep=',')
eq_sichuan[['latitude', 'longitude', 'mag', 'latlon']].to_csv('sichuan_graph.csv', index=False)

# %% [markdown]
# #### 2.6 我国哪些地方比较经常发生地震？

# %%
eq_china = eq20_years[(eq20_years['latitude'] < 51.9824)
                      & (eq20_years['longitude'] < 136.1715) 
                      & (eq20_years['latitude'] > 0) 
                      & (eq20_years['longitude'] > 73.2418)]

# %%
eq_china = eq_china[['latitude', 'longitude', 'mag']]
eq_china['latitude'] = eq_china['latitude'].astype(str)
eq_china['longitude'] = eq_china['longitude'].astype(str)
eq_china['latlon'] = eq_china['longitude'].str.cat(eq_china['latitude'], sep=',')

eq_china.to_csv('eq_china.csv', index=False)
